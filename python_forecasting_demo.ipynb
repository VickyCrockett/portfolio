# %% [markdown]
# <a href="https://colab.research.google.com/github/VickyCrockett/portfolio/blob/main/python_forecasting_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greeting = 'Hello World!'
greeting
# Out:
# 'Hello World!'

# %%
import math

math.sqrt(5)
# Out:
# 2.23606797749979

# %%
import pandas as pd

# %%
# Load the Peyton Manning dataset
my_table = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')
my_table
# Out:
#               ds          y
# 0     2007-12-10   9.590761
# 1     2007-12-11   8.519590
# 2     2007-12-12   8.183677
# 3     2007-12-13   8.072467
# 4     2007-12-14   7.893572
# ...          ...        ...
# 2900  2016-01-16   7.817223
# 2901  2016-01-17   9.273878
# 2902  2016-01-18  10.333775
# 2903  2016-01-19   9.125871
# 2904  2016-01-20   8.891374
#
# [2905 rows x 2 columns]

# %%
import plotly.graph_objects as go

# Create the plot
my_fig_workspace = go.Figure()

my_fig_workspace.add_trace(go.Scatter(x=my_table['ds'], y=my_table['y'], mode='lines', name='Page Views'))

my_fig_workspace.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from prophet import Prophet

# %%
my_forecast_workspace = Prophet()
my_forecast_workspace.fit(df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzzid4_yk/nyfktojq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpzzid4_yk/1ulsduyd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41961', 'data', 'file=/tmp/tmpzzid4_yk/nyfktojq.json', 'init=/tmp/tmpzzid4_yk/1ulsduyd.json', 'output', 'file=/tmp/tmpzzid4_yk/prophet_modeld3_7wqix/prophet_model-20240321174408.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 17:44:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 17:44:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future = my_forecast_workspace.make_future_dataframe(periods=365)
forecast = my_forecast_workspace.predict(future)

# %%
# Create the plot with the forecast
my_fig2_workspace = go.Figure()

my_fig2_workspace.add_trace(go.Scatter(x=my_table['ds'], y=my_table['y'], mode='lines', name='Actual'))
my_fig2_workspace.add_trace(go.Scatter(x=forecast['ds'], y=forecast['yhat'], mode='lines', name='Forecast'))

my_fig2_workspace.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
my_fig3_workspace = go.Figure()

my_fig3_workspace.add_trace(go.Scatter(x=my_table['ds'], y=my_table['y'], mode='lines', name='Actual'))
my_fig3_workspace.add_trace(go.Scatter(x=forecast['ds'], y=forecast['yhat'], mode='lines', name='Forecast'))
my_fig3_workspace.add_trace(go.Scatter(x=forecast['ds'], y=forecast['yhat_upper'], mode='lines', name='Upper Bound',
                                       line=dict(width=0)))
my_fig3_workspace.add_trace(go.Scatter(x=forecast['ds'], y=forecast['yhat_lower'], mode='lines', name='Lower Bound',
                                       fill='tonexty',  # Fill the area between this trace and the next one
                                       fillcolor='rgba(68, 68, 68, 0.3)',  # Light grey fill with some transparency
                                       line=dict(width=0)))


my_fig3_workspace.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
